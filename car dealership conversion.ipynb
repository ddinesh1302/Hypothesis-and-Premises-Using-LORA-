# %%
import csv
import os

# The data mapped from the YAML file
data = [
    ["What car would fit my $35,000 budget and daily commute?", "Vehicle Recommendation: Suggesting cars based on budget and usage."],
    ["How does the Tesla Model 3 compare to the BMW i4?", "Model Comparison: Comparing features, pricing, and performance of car models."],
    ["I'd like to book a slot for a test drive this Saturday.", "Test Drive Scheduling: Assisting customers in booking test drives."],
    ["What are the current interest rates for a 60-month loan?", "Financing Advisory: Providing loan, EMI, and financing options."],
    ["Which insurance plan provides the best bumper-to-bumper coverage?", "Insurance Guidance: Advising suitable car insurance plans."],
    ["Can you give me a price estimate for my 2019 sedan exchange?", "Trade-In Evaluation: Estimating value of old cars for exchange."],
    ["Is the top-trim hybrid variant currently in stock?", "Inventory Availability: Checking stock status of car models and variants."],
    ["What is the difference between the Premium and Limited trims?", "Variant Selection Advice: Helping choose the right variant and trim."],
    ["Should I buy a diesel or an electric car for highway driving?", "Fuel Type Advisory: Recommending petrol, diesel, hybrid, or EV options."],
    ["What is the approximate cost of the first three services?", "Maintenance Cost Estimation: Estimating service and upkeep costs."],
    ["When should I bring my car in for its second maintenance check?", "Service Schedule Guidance: Providing periodic maintenance schedules."],
    ["What exactly is covered under the 5-year extended warranty?", "Warranty Information: Explaining standard and extended warranties."],
    ["Do you have any recommendations for roof racks or floor mats?", "Accessory Recommendation: Suggesting genuine car accessories."],
    ["When is the earliest I can take delivery of my new booking?", "Delivery Timeline Advisory: Informing expected delivery dates."],
    ["Can you explain the RTO registration process for my state?", "Registration Assistance: Guiding through RTO and registration process."],
    ["What identity documents do I need to finalize the purchase?", "Documentation Support: Listing required purchase documents."],
    ["Are there any hidden discounts or seasonal deals I can get?", "Pricing Negotiation Tips: Advising on best deals and discounts."],
    ["Where is the nearest authorized service center to my home?", "After-Sales Support Info: Explaining service center and support options."],
    ["My car won't start; can you send a tow truck?", "Roadside Assistance Info: Providing breakdown and emergency support details."],
    ["How can I drive more efficiently to save on fuel costs?", "Mileage Optimization Tips: Advising on improving fuel efficiency."],
    ["Does this model come with blind-spot monitoring and ADAS?", "Safety Feature Explanation: Explaining airbags, ADAS, and safety tech."],
    ["What is the procedure for transferring my car's registration to a buyer?", "Ownership Transfer Guidance: Assisting with resale and ownership transfer."],
    ["Has there been a safety recall for my vehicle's VIN?", "Recall Information: Informing about manufacturer recalls."],
    ["Can I choose a custom leather color for the interior?", "Customization Advisory: Advising on paint, interior, and upgrades."],
    ["Where can I find a list of compatible fast chargers nearby?", "EV Charging Guidance: Explaining charging options and infrastructure."],
    ["Do you offer any 12-month car subscription or leasing programs?", "Subscription & Leasing Info: Providing car lease and subscription options."],
    ["We need to buy 15 vehicles for our corporate fleet.", "Fleet Sales Advisory: Supporting corporate and bulk purchases."],
    ["What are the special offers available for the festive month?", "Seasonal Offer Updates: Informing festive and seasonal discounts."],
    ["Is there a demo vehicle at the showroom I can sit in?", "Demo Vehicle Information: Explaining demo and display car options."],
    ["What is the average rating for your service department?", "Customer Feedback Analysis: Analyzing reviews and satisfaction."],
    ["How do I start an insurance claim for this dent?", "Insurance Claim Support: Assisting with claim procedures."],
    ["Do you offer a pre-paid maintenance package for 3 years?", "Extended Service Plans: Advising on AMC and service packages."],
    ["What items should I check during the pre-delivery walk-around?", "Pre-Delivery Inspection: Explaining PDI checklist."],
    ["Does this vehicle meet the latest emission regulations?", "Compliance & Emission Info: Explaining BS norms and emissions."],
    ["When will my car's infotainment system get the next update?", "Software Update Advisory: Informing OTA and system updates."],
    ["Are there any original brake pads available in stock?", "Spare Parts Availability: Checking parts stock and pricing."],
    ["What will be the market value of this car in 4 years?", "Resale Value Advisory: Estimating future resale value."],
    ["What is the total cost including taxes, fuel, and repairs?", "Ownership Cost Analysis: Calculating total cost of ownership."],
    ["Can I see the maintenance history of this used car?", "Vehicle History Report: Providing accident and service history details."],
    ["Am I eligible for a car loan with my current salary?", "Loan Eligibility Check: Assessing customer eligibility for car loans."],
    ["Can you help me figure out my monthly payments for this model?", "EMI Calculator Assistance: Helping calculate monthly installments."],
    ["Do I get an extra discount if I trade in my old car?", "Exchange Bonus Information: Informing offers on old car exchange."],
    ["Where is your dealership located in the downtown area?", "Dealer Location Guidance: Providing nearby showroom details."],
    ["I need to cancel my order; what is the refund process?", "Booking Cancellation Support: Assisting with order cancellation process."],
    ["Is there a way to skip the waiting list for the new SUV?", "Waiting Period Reduction Tips: Advising faster delivery options."],
    ["Can someone walk me through the inspection at the time of delivery?", "Vehicle Inspection Support: Assisting during inspection at delivery."],
    ["Are there any certified pre-owned hatchbacks available?", "Used Car Advisory: Recommending certified pre-owned vehicles."],
    ["How do I participate in the upcoming company vehicle auction?", "Auction & Bulk Disposal Info: Advising on vehicle auctions."],
    ["How do I sign up for the dealership's loyalty rewards?", "Customer Loyalty Program Info: Explaining rewards and loyalty benefits."],
    ["I have a complaint about my last service; who should I contact?", "Complaint Resolution Support: Handling customer issues and escalation."]
]

# TARGET PATH: E drive
file_path = r"E:\car_dealership.csv"

try:
    with open(file_path, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(["PREMISE", "HYPOTHESIS"])
        writer.writerows(data)
    print(f"Success! The file has been saved to: {file_path}")
except PermissionError:
    print("Error: Permission denied. Try running VS Code as Administrator.")
except FileNotFoundError:
    print("Error: E: drive not found. Please make sure your drive is plugged in.")
